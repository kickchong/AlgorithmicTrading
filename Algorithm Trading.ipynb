# %% [markdown]
# ##### Algorithm Trading

# %%
a=-5
print(a)
# Out:
# -5

# %%
abs(a)
# Out:
# 5

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Apple = yf.download("AAPL",start="2014-01-01",end="2024-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
Apple
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-01-02   19.845715   19.893929   19.715000   19.754642   17.318726
# 2014-01-03   19.745001   19.775000   19.301071   19.320715   16.938311
# 2014-01-06   19.194643   19.528570   19.057142   19.426071   17.030672
# 2014-01-07   19.440001   19.498571   19.211430   19.287144   16.908878
# 2014-01-08   19.243214   19.484285   19.238930   19.409286   17.015957
# ...                ...         ...         ...         ...         ...
# 2023-12-22  195.179993  195.410004  192.970001  193.600006  193.600006
# 2023-12-26  193.610001  193.889999  192.830002  193.050003  193.050003
# 2023-12-27  192.490005  193.500000  191.089996  193.149994  193.149994
# 2023-12-28  194.139999  194.660004  193.169998  193.580002  193.580002
# 2023-12-29  193.899994  194.399994  191.729996  192.529999  192.529999
#
#                Volume
# Date
# 2014-01-02  234684800
# 2014-01-03  392467600
# 2014-01-06  412610800
# ...

# %%
ticker = ["SPY","AAPL","KO"]

# %%
stocks = yf.download(ticker,start="2014-01-01",end="2024-01-01")
# Out:
# [*********************100%%**********************]  3 of 3 completed

# %%
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2014-01-02   17.318726  29.601591  152.669144   19.754642  40.660000
# 2014-01-03   16.938311  29.455984  152.644104   19.320715  40.459999
# 2014-01-06   17.030672  29.317657  152.201752   19.426071  40.270000
# 2014-01-07   16.908878  29.405016  153.136520   19.287144  40.389999
# 2014-01-08   17.015957  29.077412  153.169907   19.409286  39.939999
# ...                ...        ...         ...         ...        ...
# 2023-12-22  193.600006  58.320000  473.649994  193.600006  58.320000
# 2023-12-26  193.050003  58.560001  475.649994  193.050003  58.560001
# 2023-12-27  193.149994  58.709999  476.510010  193.149994  58.709999
# 2023-12-28  193.580002  58.750000  476.690002  193.580002  58.750000
# 2023-12-29  192.529999  58.930000  475.309998  192.529999  58.930000
#
# ...

# %%
stocks.tail()
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2023-12-22  193.600006  58.320000  473.649994  193.600006  58.320000
# 2023-12-26  193.050003  58.560001  475.649994  193.050003  58.560001
# 2023-12-27  193.149994  58.709999  476.510010  193.149994  58.709999
# 2023-12-28  193.580002  58.750000  476.690002  193.580002  58.750000
# 2023-12-29  192.529999  58.930000  475.309998  192.529999  58.930000
#
#                               High                                Low  \
#                    SPY        AAPL         KO         SPY        AAPL
# Date
# 2023-12-22  473.649994  195.410004  58.459999  475.380005  192.970001
# 2023-12-26  475.649994  193.889999  58.709999  476.579987  192.830002
# 2023-12-27  476.510010  193.500000  58.770000  476.660004  191.089996
# 2023-12-28  476.690002  194.660004  58.869999  477.549988  193.169998
# ...

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2516 entries, 2014-01-02 to 2023-12-29
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  2516 non-null   float64
#  1   (Adj Close, KO)    2516 non-null   float64
#  2   (Adj Close, SPY)   2516 non-null   float64
#  3   (Close, AAPL)      2516 non-null   float64
#  4   (Close, KO)        2516 non-null   float64
#  5   (Close, SPY)       2516 non-null   float64
#  6   (High, AAPL)       2516 non-null   float64
#  7   (High, KO)         2516 non-null   float64
#  8   (High, SPY)        2516 non-null   float64
#  9   (Low, AAPL)        2516 non-null   float64
#  10  (Low, KO)          2516 non-null   float64
#  11  (Low, SPY)         2516 non-null   float64
#  12  (Open, AAPL)       2516 non-null   float64
#  13  (Open, KO)         2516 non-null   float64
#  14  (Open, SPY)        2516 non-null   float64
# ...

# %%
stocks.to_csv("stocksYT")

# %%
nem = yf.download("NEM",start="2014-01-01",end="2024-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
nem
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2014-01-02  23.469999  24.270000  23.410000  23.959999  19.314434  12162400
# 2014-01-03  24.170000  24.290001  23.879999  23.920000  19.282194  10233600
# 2014-01-06  24.250000  24.540001  24.000000  24.080000  19.411169   9276100
# 2014-01-07  23.850000  23.980000  23.510000  23.950001  19.306381   8783800
# 2014-01-08  23.690001  23.730000  23.330000  23.400000  18.863012   8027400
# ...               ...        ...        ...        ...        ...       ...
# 2023-12-22  42.349998  42.810001  42.009998  42.060001  42.060001   9132300
# 2023-12-26  42.330002  42.470001  41.799999  41.910000  41.910000   4979200
# 2023-12-27  42.040001  42.599998  41.939999  42.380001  42.380001   7687800
# 2023-12-28  42.099998  42.419998  41.680000  41.700001  41.700001   6259400
# 2023-12-29  41.410000  41.570000  41.230000  41.389999  41.389999   6985100
#
# [2516 rows x 6 columns]

# %%
nem.to_csv("nemYT.csv")

# %%
stocksCSV = pd.read_csv("stocksYT.csv")

# %%
nem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2516 entries, 2014-01-02 to 2023-12-29
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2516 non-null   float64
#  1   High       2516 non-null   float64
#  2   Low        2516 non-null   float64
#  3   Close      2516 non-null   float64
#  4   Adj Close  2516 non-null   float64
#  5   Volume     2516 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 137.6 KB

# %%
stocks.to_csv("stocksYT")

# %%
stocks.to_csv("stocksYT.csv")

# %%
stocksCSV = pd.read_csv("stocksYT.csv")

# %%
stocksCSV
# Out:
#       Unnamed: 0           Adj Close         Adj Close.1         Adj Close.2  \
# 0            NaN                AAPL                  KO                 SPY
# 1           Date                 NaN                 NaN                 NaN
# 2     2014-01-02    17.3187255859375  29.601591110229492   152.6691436767578
# 3     2014-01-03  16.938310623168945  29.455984115600586  152.64410400390625
# 4     2014-01-06  17.030672073364258  29.317657470703125  152.20175170898438
# ...          ...                 ...                 ...                 ...
# 2513  2023-12-22  193.60000610351562   58.31999969482422   473.6499938964844
# 2514  2023-12-26   193.0500030517578  58.560001373291016   475.6499938964844
# 2515  2023-12-27  193.14999389648438  58.709999084472656    476.510009765625
# 2516  2023-12-28   193.5800018310547               58.75  476.69000244140625
# 2517  2023-12-29  192.52999877929688   58.93000030517578  475.30999755859375
#
# ...

# %%
stocksCSV = pd.read_csv("stocksYT.csv",header=[0,1])

# %%
stocksCSV
# Out:
#      Unnamed: 0_level_0   Adj Close                              Close  \
#      Unnamed: 0_level_1        AAPL         KO         SPY        AAPL
# 0                  Date         NaN        NaN         NaN         NaN
# 1            2014-01-02   17.318726  29.601591  152.669144   19.754642
# 2            2014-01-03   16.938311  29.455984  152.644104   19.320715
# 3            2014-01-06   17.030672  29.317657  152.201752   19.426071
# 4            2014-01-07   16.908878  29.405016  153.136520   19.287144
# ...                 ...         ...        ...         ...         ...
# 2512         2023-12-22  193.600006  58.320000  473.649994  193.600006
# 2513         2023-12-26  193.050003  58.560001  475.649994  193.050003
# 2514         2023-12-27  193.149994  58.709999  476.510010  193.149994
# 2515         2023-12-28  193.580002  58.750000  476.690002  193.580002
# 2516         2023-12-29  192.529999  58.930000  475.309998  192.529999
#
# ...

# %%
stocks.describe()
# Out:
#          Adj Close                                  Close               \
#               AAPL           KO          SPY         AAPL           KO
# count  2516.000000  2516.000000  2516.000000  2516.000000  2516.000000
# mean     75.985044    42.635786   279.742255    77.920721    49.170334
# std      56.731116    10.291671    97.179289    56.226768     7.521232
# min      15.648319    27.009808   145.366196    17.849285    37.099998
# 25%      27.231721    33.570037   184.188110    29.803750    42.689999
# 50%      46.091772    39.658762   256.585358    48.107500    46.455000
# 75%     132.652615    50.866385   378.694008   134.562496    55.022500
# max     198.110001    62.817841   476.690002   198.110001    66.209999
#
#                            High                                    Low  \
#                SPY         AAPL           KO          SPY         AAPL
# count  2516.000000  2516.000000  2516.000000  2516.000000  2516.000000
# ...

# %%
stocks.loc[:,"Close"]
# Out:
#                   AAPL         KO         SPY
# Date
# 2014-01-02   19.754642  40.660000  182.919998
# 2014-01-03   19.320715  40.459999  182.889999
# 2014-01-06   19.426071  40.270000  182.360001
# 2014-01-07   19.287144  40.389999  183.479996
# 2014-01-08   19.409286  39.939999  183.520004
# ...                ...        ...         ...
# 2023-12-22  193.600006  58.320000  473.649994
# 2023-12-26  193.050003  58.560001  475.649994
# 2023-12-27  193.149994  58.709999  476.510010
# 2023-12-28  193.580002  58.750000  476.690002
# 2023-12-29  192.529999  58.930000  475.309998
#
# [2516 rows x 3 columns]

# %%
close = stocks.loc[:,"Close"].copy()

# %%
close
# Out:
#                   AAPL         KO         SPY
# Date
# 2014-01-02   19.754642  40.660000  182.919998
# 2014-01-03   19.320715  40.459999  182.889999
# 2014-01-06   19.426071  40.270000  182.360001
# 2014-01-07   19.287144  40.389999  183.479996
# 2014-01-08   19.409286  39.939999  183.520004
# ...                ...        ...         ...
# 2023-12-22  193.600006  58.320000  473.649994
# 2023-12-26  193.050003  58.560001  475.649994
# 2023-12-27  193.149994  58.709999  476.510010
# 2023-12-28  193.580002  58.750000  476.690002
# 2023-12-29  192.529999  58.930000  475.309998
#
# [2516 rows x 3 columns]

# %%
#matplotlib inline
import seaborn as sb
plt.style.use("seaborn")
# Out:
# C:\Users\HoOn\AppData\Local\Temp\ipykernel_14252\757466200.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
close.plot(figsize=(15,8),frontsize=12)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 close.plot(figsize=(15,8),frontsize=12)
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     972             label_name = label_kw or data.columns
#     973             data.columns = label_name
# --> 975 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:448, in MPLPlot.generate(self)
#     446 self._compute_plot_data()
# ...
